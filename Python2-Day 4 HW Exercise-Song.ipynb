# %%
# Is there an efficient way of doing this? (edit student/faculty/class)

import csv
from abc import ABC, abstractmethod

class Course :
    """Stores information for one class"""
    def __init__(self, ID, name, description) :
        """Initialize ID, name and description attributes"""
        self.__ID = ID
        self.__name = name
        self.__description = description
        
    def change_course_id(self, new_id):
        """edit class id"""
        self.__ID = new_id
        
    def change_course_name(self, new_name):
        """edit class name"""
        self.__name = new_name
    
    def change_course_desc(self, new_desc):
        """edit class description"""
        self.__description = new_desc
    
    def get_course_id(self) :
        return self.__ID
        
    def get_course_name(self) :
        return self.__name
        
    def get_course_desc(self) :
        return self.__description
    
    def view_course_info(self):
        """returns course id, name and description"""
        return f"Class Id: {self.__ID} \nClass name: {self.__name} \nClass Description: {self.__description} \n"
    
class Classes : 
    """Stores list of classes"""
    def __init__(self) :
        """Initialize classes_list attribute"""
        self.classes_list = []
        
    def add_class(self, new_class) :   
        self.classes_list.append(new_class)
        
    def edit_class(self) :
        """asks for id of class, then selects which Course attribute to change"""
        ent_id = input("Enter id of class: ")
        
        found = False
        
        for n in range (0, len(self.classes_list)) :
            if ent_id == self.classes_list[n].get_course_id() :
                found = True
                break
            
        if not found :
            print("Id not found")
            
        else: 
            print("What would you like to change?")
            change = input("Select (i)d, (n)ame or (d)escription: ")
            change = change.lower()
                
            if change == 'i' or change == 'id' :
                new_class_id = input("Enter new class id: ")
                self.classes_list[n].change_course_id(new_class_id)
                print("Class id changed")
                
            elif change == 'n' or change == 'name' :
                new_class_name = input("Enter new class name: ")
                self.classes_list[n].change_course_name(new_class_name)
                print("Class name changed")
                
            elif change == 'd' or change == 'description' :
                new_class_desc = input("Enter new class description: ")
                self.classes_list[n].change_course_desc(new_class_desc)
                print("Class description updated")
                    
    def load_data(self, filename) :
        """imports class data from csv file"""
        with open(filename) as data_file :
            csv_data = csv.reader(data_file)
            for row in csv_data :    # 0: class id, 1: class name, 2: class descrption
                if len(row) == 3 :   # skips blank rows
                    course = Course(row[0].lstrip(), row[1].lstrip(), row[2].lstrip())  # remove left blanks
                    self.classes_list.append(course)
                    
    def save_data(self, filename) :
        """exports class data as csv file"""
        file = open(filename, "w")
        csv_out = csv.writer(file)
        for course in self.classes_list :
            msg = [course.get_course_id(), course.get_course_name(), course.get_course_desc()]
            csv_out.writerow(msg)
                
    def view_class_info(self) :
        """prints all classes id, name and description"""
        for n in range (1, len(self.classes_list)) :
            print(self.classes_list[n].view_course_info())
            
            
class Person :
    """Stores information for one Admin, Student or Faculty person"""
    def __init__(self, ID, name, email, password) :
        """Initialize ID, name, email and password attributes"""
        self.__ID = ID
        self.__name = name
        self.__email = email
        self.__password = password
        
    def change_id(self, new_id):
        """edit person id"""
        self.__ID = new_id
        
    def change_name(self, new_name):
        """edit person name"""
        self.__name = new_name
        
    def change_email(self, new_email):
        """edit person emmail"""
        self.__email = new_email
    
    def change_password(self, new_password):
        """edit person password"""
        self.__password = new_password 
        
    def check_login(self, email, password):
        """return True if email and password match"""
        return (email == self.__email) and (password == self.__password) 
        
    def get_id(self):
        """returns private ID attribute"""
        return self.__ID
    
    def get_name(self):
        """returns private name attribute"""
        return self.__name
    
    def get_email(self):
        """Returns private email attribute"""
        return self.__email
    
    def get_password(self):
        """Returns private password attribute"""
        return self.__password 

class People :
    """Stores list of people (students/faculty)"""
    def __init__(self) :
        """Initialize people_list attribute"""
        self.people_list = []
        
    def add_person(self, new_person) :
        self.people_list.append(new_person)
        
    def edit_person(self) :
        """asks for id of person, then selects which Person attribute to change"""
        ent_id = input("Enter id of person: ")
        
        found = False
        
        for n in range (0, len(self.classes_list)) :
            if ent_id == self.people_list[n].get_id() :
                found = True
                break
            
        if not found :
            print("Id not found")
            
        else: 
            print("What would you like to change?")
            change = input("Select (i)d, (n)ame, (e)mail or (p)assword: ")
            change = change.lower()
                
            if change == 'i' or change == 'id' :
                new_id = input("Enter their new id: ")
                self.people_list[n].change_id(new_class_id)
                print("Id changed")
                
            elif change == 'n' or change == 'name' :
                new_class_name = input("Enter their new name: ")
                self.people_list[n].change_name(new_class_name)
                print("Name changed")
                
            elif change == 'e' or change == 'email' :
                new_class_desc = input("Enter their current email: ")
                self.people_list[n].change_email(new_class_email)
                print("Email updated")
                
            elif change == 'p' or change == 'password' :
                new_class_desc = input("Enter new password: ")
                self.people_list[n].change_password(new_class_password)
                print("Password changed")
                
    def find_login(self, email, password) :
        """return True if matching email and password are found"""
        found_email = False
        
        for n in range (0, len(self.people_list)) :
            if email == self.people_list[n].get_email() :
                found_email = True
                break
            
        if not found_email :
            return False
            
        else :
            return self.people_list[n].check_login(email, password)
        
        
    def load_data(self, filename) :
        """imports Person information from csv file"""
        with open(filename) as data_file :
            csv_data = csv.reader(data_file)
            for row in csv_data :    # 0: person id, 1: name, 2:email, 3:password  
                if len(row) == 4 :   # skips blank rows
                    new_person = Person(row[0].strip(), row[1].strip(), row[2].strip(), row[3].strip())  
                    self.people_list.append(new_person)
                    
    def save_data(self, filename) :
        """exports Person information to csv file"""
        file = open(filename, "w")
        csv_out = csv.writer(file)
        for person in self.people_list :
            msg = [person.get_id(), person.get_name(), person.get_email(), person.get_password()]
            csv_out.writerow(msg)
    
    @abstractmethod
    def view_info(self) :
        """Will display id and name of all people in list"""
        pass

class Admins(People):
    """Placeholder for list of Admins""" #currently there is only one admin (me)
    pass
    
class Faculties(People) :
    def view_info(self) :
        """Prints id and name of all faculty members"""
        for n in range (1, len(self.people_list)) :
            print(f"Faculty Id:{self.people_list[n].get_id()} \nFaculty name: {self.people_list[n].get_name()} \n")
            
class Students(People) :
    def view_info(self) :
        """Prints id and name of all students"""
        for n in range (1, len(self.people_list)) :
            print(f"Student Id:{self.people_list[n].get_id()} \nStudent name: {self.people_list[n].get_name()} \n")

# %%
#main program
#Only one admin --> me

def admin_options() : # prints main menu
    print("""
    Options:
    1 - Add Student
    2 - Add Faculty
    3 - Edit Student
    4 - Edit Faculty
    5 - Add Class
    6 - Edit Class
    9 - View All information
    Enter "q" to quit
    """)
    
def non_admin_options(): # menu for students/faculty
    print("""
    Options:
    9 - View All information
    Enter "q" to quit
    """)
    
def user_login(user, user_list) : # user had better remember their email & password or they're stuck
    print(f"Welcome {user}")
    
    while True:
        ent_email = input("Please enter in your email: ")
        ent_pass = input("Please enter in your password: ")      

        if user_list.find_login(ent_email, ent_pass) :
            print("You have logged in!")
            break

        else :
            print("Invalid email/password")
    

admins = Admins()
students = Students()
faculties = Faculties()
classes = Classes()

admins.add_person(Person('999', 'Phil Song', 'admin@email.com', 'password'))

students.load_data('students.csv')
faculties.load_data('faculties.csv')
classes.load_data('classes.csv')

print("Welcome to MC's School System \nWould you like to login? (Y/N) ")
login = input()
login = login.upper()

if login == 'Y' or login == 'YES':
    while (login != 'A' and login != 'ADMIN' and 
           login != 'F' and login != 'FACULTY' and 
           login != 'S' and login != 'STUDENT'): 
        print("Would you like to login as an (A)dmin, (F)aculty, or (S)tudent?") #user must pick valid option or it will loop
        login = input()
        login = login.upper()
        

    if login == 'A' or login == "ADMIN" :
        
        user_login("Admin", admins)
        
        while True:
            admin_options()
            option = input("> ")   

            if option == 'q' or option == 'Q' :
                students.save_data('students.csv')
                faculties.save_data('faculties.csv')
                classes.save_data('classes.csv')
                # no admin data saved because it's only for me
                break
                
            elif option == '1' :
                person_id = input("Create id: ")
                name = input("Enter name: ")
                email = input("Enter email: ")
                password = input("Create password: ")

                new_student = Person(person_id, name, email, password)
                students.add_person(new_student)
                print("Added new Student")

            elif option == '2' :
                person_id = input("Create id: ")
                name = input("Enter name: ")
                email = input("Enter email: ")
                password = input("Create password: ")

                new_faculty = Person(person_id, name, email, password)
                
                faculties.add_person(new_faculty)
                print("Added new Faculty")

            elif option == '3' :
                students.edit_person()

            elif option == '4' :
                faculties.edit_person()

            elif option == '5' :
                class_id = input("Create class id: ")
                name = input("Enter class name: ")
                description = input("Enter class descrption: ")

                new_class = Course(class_id, name, description)
                classes.add_class(new_class)
                print("Added new Class") 

            elif option == '6' :
                classes.edit_class()


            elif option == '9' :
                print("\nAll Students:\n")
                students.view_info()
                    
                print("All Faculty:\n")
                faculties.view_info()
                     
                print("All Classes:\n")
                classes.view_class_info()
               
    if login == 'F' or login == "FACULTY" :
        user_login("Faculty", faculties) #
        
        while True:
            non_admin_options()
            option = input("> ")
            
            if option == 'q' or option == 'Q' :
                break
            
            elif option == '9' :
                print("\nAll Students:\n") 
                students.view_info()
                    
                print("All Faculty:\n")
                faculties.view_info()
                     
                print("All Classes:\n")
                classes.view_class_info()
        
    if login == 'S' or login == "STUDENT" :
        user_login("Student", students)
        
        while True:
            non_admin_options()
            option = input("> ")
            
            if option == 'q' or option == 'Q' :
                break
            
            elif option == '9' :
                print("\nAll Students:\n")
                students.view_info()
                    
                print("All Faculty:\n")
                faculties.view_info()
                     
                print("All Classes:\n")
                classes.view_class_info()
    

print("\nBYE BYE")
# Out:
# Welcome to MC's School System
# Would you like to login? (Y/N)
# y
# Would you like to login as an (A)dmin, (F)aculty, or (S)tudent?
# s
# Welcome Student
# Please enter in your email: Student1@email.com
# Please enter in your password: Student1
# You have logged in!
#
#     Options:
#     9 - View All information
#     Enter "q" to quit
#
# > 9
#
# All Students:
#
# Student Id:1
# Student name: Student1
#
# Student Id:2
# Student name: Student2
#
# Student Id:3
# Student name: Student3
#
# All Faculty:
#
# Faculty Id:1
# Faculty name: Faculty1
#
# Faculty Id:2
# Faculty name: Faculty2
#
# Faculty Id:3
# Faculty name: Faculty3
#
# All Classes:
#
# Class Id: 1
# Class name: Java 1
# Class Description: Welcome to Java 1
#
# Class Id: 2
# Class name: Python 1
# Class Description: Welcome to Python 1
#
# Class Id: 3
# Class name: C++ Advanced
# Class Description: Welcome to Advanced C++
#
#
#     Options:
#     9 - View All information
#     Enter "q" to quit
#
# > q
#
# BYE BYE
